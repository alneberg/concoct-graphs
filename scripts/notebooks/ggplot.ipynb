# %%
from ggplot import *

# %%
ggplot(aes(x='date', y='beef'), data=meat) + \
    geom_point(color='lightblue') + \
    geom_line(alpha=0.25) + \
    stat_smooth(span=.05, color='black')
# Out:
# <ggplot: (6124429)>

# %%
ggplot(diamonds, aes('carat', 'price')) + \
    geom_point(alpha=1/20.) + \
    ylim(0, 20000)
# Out:
# <ggplot: (5743001)>

# %%
import numpy as np
import pandas as p

# %%
C = np.array([[0., -0.7], [3.5, .7]])
X = np.r_[np.dot(np.random.randn(n, 2), C),
          np.random.randn(n, 2) + np.array([3, 3])]

Y = X[:,0] >= 2
x_df['cond'] = map(lambda n: int(n), Y)

# %%
ggplot(x_df, aes(0, 1, color='cond')) +\
    geom_point(alpha=1/2.) +\
    ylim(0, 6)
# Out:
# <ggplot: (6321737)>

# %%
int(False)
# Out:
# 0

# %%
int(True)
# Out:
# 1
